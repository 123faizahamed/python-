# %%
pip install networks
# Out:
# Requirement already satisfied: networks in c:\users\admin\cse\lib\site-packages (0.3.7)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: jsonpickle in c:\users\admin\cse\lib\site-packages (from networks) (3.0.2)
# Requirement already satisfied: numpy in c:\users\admin\cse\lib\site-packages (from networks) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\admin\cse\lib\site-packages (from networks) (3.5.2)
# Requirement already satisfied: scipy in c:\users\admin\cse\lib\site-packages (from networks) (1.9.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\cse\lib\site-packages (from matplotlib->networks) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\cse\lib\site-packages (from matplotlib->networks) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\cse\lib\site-packages (from matplotlib->networks) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\cse\lib\site-packages (from matplotlib->networks) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\cse\lib\site-packages (from matplotlib->networks) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\cse\lib\site-packages (from matplotlib->networks) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\cse\lib\site-packages (from matplotlib->networks) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\cse\lib\site-packages (from python-dateutil>=2.7->matplotlib->networks) (1.16.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def dist(a,b):
    (x1, y1) = a
    (x2, y2) = b
    return ((x1 - x2) ** 2 + (y1 - y2) **2)** 0.5

# %%
G = nx.grid_graph(dim=[4, 4])
nx.set_edge_attributes(G, {e: e[1][0] * 2 for e in G.edges()}, "cost")

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels = True, node_color='brown')
edge_labels = nx.get_edge_attributes(G, "cost")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.show()

# %%
path = nx.astar_path(G, (0, 0), (2, 2), heuristic=dist, weight="cost")
length = nx.astar_path_length(G, (0, 0), (2, 2), heuristic=dist, weight="cost")

# %%
print('path :',path)
# Out:
# path : [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]

# %%
print('path length',length)
# Out:
# path length 6
